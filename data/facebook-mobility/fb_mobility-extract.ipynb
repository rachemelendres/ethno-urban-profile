# %%
import pandas as pd

# %%
df = pd.read_csv("fb-mobility-data-2021.txt",delimiter="\t")
df
# Out:
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3170: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                  ds country polygon_source   polygon_id polygon_name  \
# 0        2021-01-01     AGO           GADM  AGO.10.10_1      Lubango
# 1        2021-01-02     AGO           GADM  AGO.10.10_1      Lubango
# 2        2021-01-03     AGO           GADM  AGO.10.10_1      Lubango
# 3        2021-01-04     AGO           GADM  AGO.10.10_1      Lubango
# 4        2021-01-05     AGO           GADM  AGO.10.10_1      Lubango
# ...             ...     ...            ...          ...          ...
# 4061180  2021-09-27     ZWE           GADM    ZWE.6.6_1       Zvimba
# 4061181  2021-09-29     ZWE           GADM    ZWE.6.6_1       Zvimba
# 4061182  2021-04-27     ZWE           GADM    ZWE.9.1_1   Beitbridge
# ...

# %%
ph_2021 = df[df['country'] == 'PHL']
ph_2021

# %%
ph_2021.to_csv('ph_mobility_2021.csv', index=False)

# %%
df2 = pd.read_csv("fb-mobility-data-2020.txt",delimiter="\t")
df2
# Out:
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3170: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                  ds country polygon_source   polygon_id polygon_name  \
# 0        2020-03-01     AGO           GADM  AGO.10.10_1      Lubango
# 1        2020-03-02     AGO           GADM  AGO.10.10_1      Lubango
# 2        2020-03-03     AGO           GADM  AGO.10.10_1      Lubango
# 3        2020-03-04     AGO           GADM  AGO.10.10_1      Lubango
# 4        2020-03-05     AGO           GADM  AGO.10.10_1      Lubango
# ...             ...     ...            ...          ...          ...
# 5229337  2020-12-12     ZWE           GADM    ZWE.9.1_1   Beitbridge
# 5229338  2020-12-13     ZWE           GADM    ZWE.9.1_1   Beitbridge
# 5229339  2020-12-17     ZWE           GADM    ZWE.9.1_1   Beitbridge
# ...

# %%
ph_2020 = df2[df2['country'] == 'PHL']
ph_2020
# Out:
#                  ds country polygon_source  polygon_id  polygon_name  \
# 3365893  2020-03-02     PHL           GADM  PHL.1.10_1   Lagangilang
# 3365894  2020-03-04     PHL           GADM  PHL.1.10_1   Lagangilang
# 3365895  2020-03-05     PHL           GADM  PHL.1.10_1   Lagangilang
# 3365896  2020-03-01     PHL           GADM   PHL.1.1_1       Bangued
# 3365897  2020-03-02     PHL           GADM   PHL.1.1_1       Bangued
# ...             ...     ...            ...         ...           ...
# 3643386  2020-12-27     PHL           GADM   PHL.9.5_1  Lamitan City
# 3643387  2020-12-28     PHL           GADM   PHL.9.5_1  Lamitan City
# 3643388  2020-12-29     PHL           GADM   PHL.9.5_1  Lamitan City
# 3643389  2020-12-30     PHL           GADM   PHL.9.5_1  Lamitan City
# 3643390  2020-12-31     PHL           GADM   PHL.9.5_1  Lamitan City
#
#          all_day_bing_tiles_visited_relative_change  \
# 3365893                                     0.01468
# ...

# %%
ph_2020.to_csv('ph_mobility_2020.csv', index=False)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b094c762-a059-479c-abcf-ec8e05d15b0d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
